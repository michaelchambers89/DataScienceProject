# %%
import pandas as pd
import numpy as np

df = pd.read_csv("/home/brendan/Desktop/Crimes_-_2001_to_present.csv", header=0, usecols=[2,3,4,5,6,8,16,17,18])

# %%
df['Date'] = pd.to_datetime(df.Date)
df['Date2'] = pd.to_datetime(df['Date']).dt.date
df.head(10)
# Out:
#                  Date                  Block  IUCR  \
# 0 2001-01-01 11:00:00        016XX E 86TH PL  1153
# 1 2017-10-08 03:00:00     092XX S RACINE AVE  0281
# 2 2017-03-28 14:00:00        026XX W 79TH ST  0620
# 3 2017-09-09 20:17:00   060XX S EBERHART AVE  0810
# 4 2017-08-26 10:00:00    001XX W RANDOLPH ST  0281
# 5 2013-02-10 00:00:00  071XX S LAFAYETTE AVE  0266
# 6 2015-01-01 00:01:00   061XX S KILBOURN AVE  1751
# 7 2017-01-01 00:01:00     027XX S WHIPPLE ST  1754
# 8 2017-07-17 10:10:00    021XX W MC LEAN AVE  0810
# 9 2017-12-28 15:55:00   011XX S MICHIGAN AVE  1153
#
#                  Primary Type                          Description  Arrest  \
# 0          DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300   False
# 1         CRIM SEXUAL ASSAULT                       NON-AGGRAVATED   False
# 2                    BURGLARY                       UNLAWFUL ENTRY   False
# 3                       THEFT                            OVER $500   False
# ...

# %%
#df['Date'] = pd.to_datetime(df.Date)
df['Time2'] = pd.to_datetime(df['Date']).dt.time
df.head(10)
# Out:
#                  Date                  Block  IUCR  \
# 0 2001-01-01 11:00:00        016XX E 86TH PL  1153
# 1 2017-10-08 03:00:00     092XX S RACINE AVE  0281
# 2 2017-03-28 14:00:00        026XX W 79TH ST  0620
# 3 2017-09-09 20:17:00   060XX S EBERHART AVE  0810
# 4 2017-08-26 10:00:00    001XX W RANDOLPH ST  0281
# 5 2013-02-10 00:00:00  071XX S LAFAYETTE AVE  0266
# 6 2015-01-01 00:01:00   061XX S KILBOURN AVE  1751
# 7 2017-01-01 00:01:00     027XX S WHIPPLE ST  1754
# 8 2017-07-17 10:10:00    021XX W MC LEAN AVE  0810
# 9 2017-12-28 15:55:00   011XX S MICHIGAN AVE  1153
#
#                  Primary Type                          Description  Arrest  \
# 0          DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300   False
# 1         CRIM SEXUAL ASSAULT                       NON-AGGRAVATED   False
# 2                    BURGLARY                       UNLAWFUL ENTRY   False
# 3                       THEFT                            OVER $500   False
# ...

# %%
#df=df.drop('Date', axis=1)
#df.head(10)
# Out:
#                    Block  IUCR                Primary Type  \
# 0        016XX E 86TH PL  1153          DECEPTIVE PRACTICE
# 1     092XX S RACINE AVE  0281         CRIM SEXUAL ASSAULT
# 2        026XX W 79TH ST  0620                    BURGLARY
# 3   060XX S EBERHART AVE  0810                       THEFT
# 4    001XX W RANDOLPH ST  0281         CRIM SEXUAL ASSAULT
# 5  071XX S LAFAYETTE AVE  0266         CRIM SEXUAL ASSAULT
# 6   061XX S KILBOURN AVE  1751  OFFENSE INVOLVING CHILDREN
# 7     027XX S WHIPPLE ST  1754  OFFENSE INVOLVING CHILDREN
# 8    021XX W MC LEAN AVE  0810                       THEFT
# 9   011XX S MICHIGAN AVE  1153          DECEPTIVE PRACTICE
#
#                            Description  Arrest  Y Coordinate  Year  \
# 0  FINANCIAL IDENTITY THEFT OVER $ 300   False           NaN  2001
# 1                       NON-AGGRAVATED   False           NaN  2017
# 2                       UNLAWFUL ENTRY   False           NaN  2017
# ...

# %%
df.describe()
# Out:
#        Y Coordinate          Year
# count  6.957659e+06  7.024803e+06
# mean   1.885735e+06  2.008735e+03
# std    3.267053e+04  5.318796e+00
# min    0.000000e+00  2.001000e+03
# 25%    1.859182e+06  2.004000e+03
# 50%    1.890647e+06  2.008000e+03
# 75%    1.909263e+06  2.013000e+03
# max    1.951622e+06  2.019000e+03

# %%
df.dtypes
# Out:
# Date            datetime64[ns]
# Block                   object
# IUCR                    object
# Primary Type            object
# Description             object
# Arrest                    bool
# Y Coordinate           float64
# Year                     int64
# Updated On              object
# Date2                   object
# Time2                   object
# dtype: object

# %%
df.shape
# Out:
# (7024803, 11)

# %%
df['IUCR'].max()
# Out:
# '9901'

# %%
df_binary = df[['Date', 'Arrest']] 
df_binary.columns = ['Date', 'Arr']
df_binary.head()
# Out:
#                      Date    Arr
# 0  01/01/2001 11:00:00 AM  False
# 1  10/08/2017 03:00:00 AM  False
# 2  03/28/2017 02:00:00 PM  False
# 3  09/09/2017 08:17:00 PM  False
# 4  08/26/2017 10:00:00 AM  False

# %%
# import matplotlib.pyplot as plt  
# df_binary.plot(x='Date', y='Arr', style='o')  
# plt.title('date vs arrest')  
# plt.xlabel('Date')  
# plt.ylabel('Arr')  
# plt.show()

# %%
df_binary[df_binary["Arr"]==True]["Arr"].sum()
# Out:
# 1931001

# %%
df_binary.Arr.value_counts()
# Out:
# False    5093802
# True     1931001
# Name: Arr, dtype: int64

# %%
df.groupby('Year').count().Arrest.plot()

# %%
print(df['Year'].where(df['Arrest'] ==False))
# Out:
# 0          2001.0
# 1          2017.0
# 2          2017.0
# 3          2017.0
# 4          2017.0
#             ...
# 7024798    2019.0
# 7024799       NaN
# 7024800    2019.0
# 7024801    2014.0
# 7024802    2017.0
# Name: Year, Length: 7024803, dtype: float64

# %%
is2002=df['Year']==2002
is2002.head(10)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: Year, dtype: bool

# %%
df_2002_Arr = df[('Year'==2008)&(df.Arrest=='True')]
print(df_2002_Arr)
# Out:
# Empty DataFrame
# Columns: [Date, Block, IUCR, Primary Type, Description, Arrest, Y Coordinate, Year, Updated On, Date2, Time2]
# Index: []
# /home/brendan/.local/lib/python3.6/site-packages/pandas/core/ops/__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
arr_true=df[df['Year']==2002]
print(arr_true)
# Out:
#                        Date                  Block  IUCR         Primary Type  \
# 104     2002-09-26 13:30:00        034XX W 79TH ST  0460              BATTERY
# 105     2002-10-01 19:00:00      022XX W NORTH AVE  0910  MOTOR VEHICLE THEFT
# 112     2002-11-05 16:40:00    063XX S ROCKWELL ST  031A              ROBBERY
# 192     2002-03-28 21:08:36         004XX E 133 ST  0560              ASSAULT
# 402     2002-01-05 21:24:00         007XX E 103 ST  0820                THEFT
# ...                     ...                    ...   ...                  ...
# 3750966 2002-01-01 07:00:00   022XX S ST LOUIS AVE  0840                THEFT
# 3753033 2002-02-03 00:00:00   051XX W FERDINAND ST  0840                THEFT
# 3755496 2002-07-01 12:00:00     022XX W ARTHUR AVE  0840                THEFT
# 3759588 2002-08-01 09:00:00        020XX W 82ND PL  0840                THEFT
# 3760891 2002-08-09 15:00:00  067XX S CHAMPLAIN AVE  0840                THEFT
#
# ...

# %%
df.to_csv("newDataSet.csv", index=False, encoding='utf8')

# %%
df.describe()
# Out:
#        Y Coordinate          Year         Month
# count  6.957659e+06  7.024803e+06  7.024803e+06
# mean   1.885735e+06  2.008735e+03  6.547139e+00
# std    3.267053e+04  5.318796e+00  3.333618e+00
# min    0.000000e+00  2.001000e+03  1.000000e+00
# 25%    1.859182e+06  2.004000e+03  4.000000e+00
# 50%    1.890647e+06  2.008000e+03  7.000000e+00
# 75%    1.909263e+06  2.013000e+03  9.000000e+00
# max    1.951622e+06  2.019000e+03  1.200000e+01

# %%
import pandas as pd
import numpy as np

df_modified_file = pd.read_csv("newDataSet.csv")

# %%
df_modified_file.head(10)
# Out:
#                   Date                  Block  IUCR  \
# 0  2001-01-01 11:00:00        016XX E 86TH PL  1153
# 1  2017-10-08 03:00:00     092XX S RACINE AVE  0281
# 2  2017-03-28 14:00:00        026XX W 79TH ST  0620
# 3  2017-09-09 20:17:00   060XX S EBERHART AVE  0810
# 4  2017-08-26 10:00:00    001XX W RANDOLPH ST  0281
# 5  2013-02-10 00:00:00  071XX S LAFAYETTE AVE  0266
# 6  2015-01-01 00:01:00   061XX S KILBOURN AVE  1751
# 7  2017-01-01 00:01:00     027XX S WHIPPLE ST  1754
# 8  2017-07-17 10:10:00    021XX W MC LEAN AVE  0810
# 9  2017-12-28 15:55:00   011XX S MICHIGAN AVE  1153
#
#                  Primary Type                          Description  Arrest  \
# 0          DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300   False
# 1         CRIM SEXUAL ASSAULT                       NON-AGGRAVATED   False
# 2                    BURGLARY                       UNLAWFUL ENTRY   False
# 3                       THEFT                            OVER $500   False
# ...

# %%
df_modified_file['Arrest_number'] = (df_modified_file[['Arrest']] == True).sum(axis=1)
df_modified_file.head(10)
# Out:
#                   Date                  Block  IUCR  \
# 0  2001-01-01 11:00:00        016XX E 86TH PL  1153
# 1  2017-10-08 03:00:00     092XX S RACINE AVE  0281
# 2  2017-03-28 14:00:00        026XX W 79TH ST  0620
# 3  2017-09-09 20:17:00   060XX S EBERHART AVE  0810
# 4  2017-08-26 10:00:00    001XX W RANDOLPH ST  0281
# 5  2013-02-10 00:00:00  071XX S LAFAYETTE AVE  0266
# 6  2015-01-01 00:01:00   061XX S KILBOURN AVE  1751
# 7  2017-01-01 00:01:00     027XX S WHIPPLE ST  1754
# 8  2017-07-17 10:10:00    021XX W MC LEAN AVE  0810
# 9  2017-12-28 15:55:00   011XX S MICHIGAN AVE  1153
#
#                  Primary Type                          Description  Arrest  \
# 0          DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300   False
# 1         CRIM SEXUAL ASSAULT                       NON-AGGRAVATED   False
# 2                    BURGLARY                       UNLAWFUL ENTRY   False
# 3                       THEFT                            OVER $500   False
# ...

# %%
df_modified_file.groupby('Year').sum().Arrest_number.plot()

# %%
# import matplotlib.pyplot as plt  
# df_modified_file.plot(x='Year', y='ID', style='o')  
# plt.title('Year vs ID')  
# plt.xlabel('Year')  
# plt.ylabel('ID')  
# plt.show()

# %%
import datetime
df_modified_file['Date'] = pd.to_datetime(df_modified_file.Date)
df_modified_file['Month'] = df_modified_file['Date'].dt.month
df_modified_file.head(10)
# Out:
#                  Date                  Block  IUCR  \
# 0 2001-01-01 11:00:00        016XX E 86TH PL  1153
# 1 2017-10-08 03:00:00     092XX S RACINE AVE  0281
# 2 2017-03-28 14:00:00        026XX W 79TH ST  0620
# 3 2017-09-09 20:17:00   060XX S EBERHART AVE  0810
# 4 2017-08-26 10:00:00    001XX W RANDOLPH ST  0281
# 5 2013-02-10 00:00:00  071XX S LAFAYETTE AVE  0266
# 6 2015-01-01 00:01:00   061XX S KILBOURN AVE  1751
# 7 2017-01-01 00:01:00     027XX S WHIPPLE ST  1754
# 8 2017-07-17 10:10:00    021XX W MC LEAN AVE  0810
# 9 2017-12-28 15:55:00   011XX S MICHIGAN AVE  1153
#
#                  Primary Type                          Description  Arrest  \
# 0          DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300   False
# 1         CRIM SEXUAL ASSAULT                       NON-AGGRAVATED   False
# 2                    BURGLARY                       UNLAWFUL ENTRY   False
# 3                       THEFT                            OVER $500   False
# ...

# %%
df_modified_file.groupby(['Month']).sum().Arrest_number.plot()

# %%
Year_2003=df[df['Year']==2003]
Year_2003.head(10)
# Out:
#                     Date                   Block  IUCR  \
# 41   2003-01-01 00:01:00    056XX S ARTESIAN AVE  1563
# 232  2003-07-26 12:00:00     040XX N LINCOLN AVE  1155
# 371  2003-07-19 00:01:00   053XX S MAPLEWOOD AVE  1752
# 727  2003-07-09 00:01:00     050XX W MAYPOLE AVE  1750
# 983  2003-06-03 09:00:00        002XX S CANAL ST  5000
# 1093 2003-03-17 20:00:00     029XX N MELVINA AVE  5093
# 1145 2003-12-16 00:01:00   003XX S MAPLEWOOD AVE  1754
# 2471 2003-01-05 21:15:00       027XX W OGDEN AVE  2024
# 2472 2003-01-03 18:00:00  039XX W IRVING PARK RD  1670
# 2473 2003-01-06 15:25:45       052XX S BISHOP ST  1811
#
#                     Primary Type                          Description  Arrest  \
# 41                   SEX OFFENSE                CRIMINAL SEXUAL ABUSE   False
# 232           DECEPTIVE PRACTICE  AGGRAVATED FINANCIAL IDENTITY THEFT   False
# 371   OFFENSE INVOLVING CHILDREN        AGG CRIM SEX ABUSE FAM MEMBER   False
# ...

# %%
Year_2003.groupby(['Month']).sum().Count.plot()

# %%
Year_2018=df[df['Year']==2018]
Year_2018.head(10000)
# Out:
#                       Date                    Block  IUCR        Primary Type  \
# 45     2018-02-04 15:25:00  044XX W WASHINGTON BLVD  1153  DECEPTIVE PRACTICE
# 55     2018-02-20 16:21:00     005XX W ARLINGTON PL  0820               THEFT
# 65     2018-02-05 00:00:00      061XX N KENMORE AVE  2820       OTHER OFFENSE
# 67     2018-01-03 15:45:00            0000X W C1 ST  0810               THEFT
# 89     2018-02-05 18:00:00      013XX N LA SALLE DR  0890               THEFT
# ...                    ...                      ...   ...                 ...
# 972687 2018-01-10 06:40:00          022XX W 37TH ST  0460             BATTERY
# 972688 2018-01-09 19:00:00          034XX W 82ND PL  0820               THEFT
# 972690 2018-01-03 11:00:00    014XX W GARFIELD BLVD  0820               THEFT
# 972691 2018-01-09 13:00:00      050XX N KIMBALL AVE  0820               THEFT
# 972692 2018-01-10 09:30:00          003XX E 47TH ST  1821           NARCOTICS
#
# ...

# %%
Year_2003.groupby(['Month']).Count.sum().plot()

# %%
Year_2018.groupby(['Month']).Count.sum().plot()

# %%
Year_2018.groupby(['Month']).Count.sum().max()
# Out:
# 4958

# %%
df.groupby(['Primary Type']).Arrest.sum()
# Out:
# Primary Type
# ARSON                                  1492.0
# ASSAULT                              100700.0
# BATTERY                              291689.0
# BURGLARY                              22869.0
# CONCEALED CARRY LICENSE VIOLATION       488.0
# CRIM SEXUAL ASSAULT                    4480.0
# CRIMINAL DAMAGE                       56221.0
# CRIMINAL TRESPASS                    145655.0
# DECEPTIVE PRACTICE                    45085.0
# DOMESTIC VIOLENCE                         1.0
# GAMBLING                              14463.0
# HOMICIDE                               4705.0
# HUMAN TRAFFICKING                         6.0
# INTERFERENCE WITH PUBLIC OFFICER      15429.0
# INTIMIDATION                            706.0
# KIDNAPPING                              754.0
# LIQUOR LAW VIOLATION                  14182.0
# MOTOR VEHICLE THEFT                   29248.0
# NARCOTICS                            722031.0
# NON - CRIMINAL                            6.0
# ...

# %%
features = ['Month','Year']

X = df_modified_file[features]
y = df_modified_file['Arrest_number']

print(X)
print(y)
# Out:
#          Month  Year
# 0            1  2001
# 1           10  2017
# 2            3  2017
# 3            9  2017
# 4            8  2017
# ...        ...   ...
# 7024798      5  2019
# 7024799      5  2019
# 7024800      5  2019
# 7024801      7  2014
# 7024802     11  2017
#
# [7024803 rows x 2 columns]
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#           ..
# 7024798    0
# 7024799    1
# 7024800    0
# 7024801    0
# 7024802    0
# Name: Arrest_number, Length: 7024803, dtype: int64

# %%
# from sklearn.tree import DecisionTreeClassifier
# from sklearn import tree
# import pydotplus
# import matplotlib.pyplot as plt
# import matplotlib.image as pltimg
# dtree = DecisionTreeClassifier()
# dtree = dtree.fit(X, y)
# data = tree.export_graphviz(dtree, out_file=None, feature_names=features)
# graph = pydotplus.graph_from_dot_data(data)
# graph.write_png('mydecisiontree.png')

# img=pltimg.imread('mydecisiontree.png')
# imgplot = plt.imshow(img)
# plt.show()

# %%
#import the necessary module
from sklearn import preprocessing
# create the Labelencoder object
le = preprocessing.LabelEncoder()
#convert the categorical columns into numeric
df_modified_file['Primary Type'] = le.fit_transform(df_modified_file['Primary Type'])
df_modified_file['Description'] = le.fit_transform(df_modified_file['Description'])
#display the initial records
df_modified_file.head(100)
# Out:
#                   Date                 Block  IUCR  Primary Type  Description  \
# 0  2001-01-01 11:00:00       016XX E 86TH PL  1153             8          155
# 1  2017-10-08 03:00:00    092XX S RACINE AVE  0281             5          234
# 2  2017-03-28 14:00:00       026XX W 79TH ST  0620             3          349
# 3  2017-09-09 20:17:00  060XX S EBERHART AVE  0810            33          256
# 4  2017-08-26 10:00:00   001XX W RANDOLPH ST  0281             5          234
# ..                 ...                   ...   ...           ...          ...
# 95 2017-12-28 14:00:00    027XX N HAMPDEN CT  1153             8          155
# 96 2017-08-04 15:00:00   003XX E RANDOLPH ST  0810            33          256
# 97 2014-11-12 00:00:00     107XX S PEORIA ST  1153             8          155
# 98 2017-07-31 08:05:00   004XX N MC CLURG CT  1310             6          341
# 99 2017-12-12 12:00:00       033XX W 47TH ST  0890            33          167
#
# ...

# %%
# select columns other than 'Opportunity Number','Opportunity Result'cols = [col for col in sales_data.columns if col not in ['Opportunity Number','Opportunity Result']]
# dropping the 'Opportunity Number'and 'Opportunity Result' columns
data = df_modified_file[["Primary Type", "Month"]]
#assigning the Oppurtunity Result column as target
target = df_modified_file['Arrest_number']
data.head(n=10)
# Out:
#                  Primary Type  Month
# 0          DECEPTIVE PRACTICE      1
# 1         CRIM SEXUAL ASSAULT     10
# 2                    BURGLARY      3
# 3                       THEFT      9
# 4         CRIM SEXUAL ASSAULT      8
# 5         CRIM SEXUAL ASSAULT      2
# 6  OFFENSE INVOLVING CHILDREN      1
# 7  OFFENSE INVOLVING CHILDREN      1
# 8                       THEFT      7
# 9          DECEPTIVE PRACTICE     12

# %%
#import the necessary module
# select columns other than 'Opportunity Number','Opportunity Result'cols = [col for col in sales_data.columns if col not in ['Opportunity Number','Opportunity Result']]
# dropping the 'Opportunity Number'and 'Opportunity Result' columns
# from sklearn.model_selection import train_test_split
# from sklearn import datasets, linear_model
# from matplotlib import pyplot as plt
# data = df_modified_file[["Primary Type", "Month"]]
# #assigning the Oppurtunity Result column as target
# target = df_modified_file['Arrest_number']
# X_train, X_test, y_train, y_test = train_test_split(data,target, test_size=0.30, random_state = 10)
# print(X_train.shape, y_train.shape)
# print (X_test.shape, y_test.shape)
# lm = linear_model.LinearRegression()
# model = lm.fit(X_train, y_train)
# predictions = lm.predict(X_test)
# print(predictions)
# The line / model
# plt.scatter(y_test, predictions)
# plt.xlabel("Values")
# plt.ylabel("Predictions")

# print("Score", model.score(X_test, y_test))

# %%
# print("Score", model.score(X_test, y_test))

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

feature_cols = ['Month', 'Year']
X = df_modified_file[feature_cols] # Features
y = df_modified_file.Arrest_number # Target variable

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) 

# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7250589696223999

# %%
print (df_modified_file.isnull().sum())
# Out:
# Date                 0
# Block                0
# IUCR                 0
# Primary Type         0
# Description          0
# Arrest               0
# Y Coordinate     67144
# Year                 0
# Updated On           0
# Date2                0
# Time2                0
# Month                0
# Arrest_number        0
# dtype: int64
